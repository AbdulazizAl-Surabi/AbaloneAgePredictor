# %% [markdown]
# # Abalone's age prediction using Regression

# %%
! pip install -r requirements.txt

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
import pickle

# %% [markdown]
# Einlesen des Abalonen-Datensatzes

# %%
df = pd.read_csv('../data/abalone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010  \
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# ## Analyse

# %% [markdown]
# ### Datenqualität

# %%
print('Deskriptive Statistiken')
print()
print(df.describe())
print()
# Out:
# Deskriptive Statistiken
#
#             Length     Diameter       Height  Whole weight  Shucked weight
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000  \
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# ### Darstellung der Balanciertheit

# %%
# Häufigkeitsverteilung der Kategorie "Geschlecht"
df['Sex'].value_counts().plot(kind='bar')
plt.title('Häufigkeitsverteilung der Kategorie "Geschlecht"')
plt.show()

# Daten ohne das Geschlecht (Spalte "Sex") filtern
numerische_merkmale = df.drop(columns=['Sex'])

# Visualisierung der Verteilung für numerische Features
numerische_merkmale.hist(figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Darstellung der Ausreißer

# %%
print("Das kategoriale Merkmal 'Geschlecht' wird zuerst mittels One-Hot-Encoding in ein Set binärer Variablen transformiert, \num es in einem maschinellen Lernmodell verwenden zu können")
df['Sex'] = df['Sex'].map({"M":0, "F":1, "I":2})
print("")


# Berechnung des ersten (Q1) und dritten Quartils (Q3) des Datensatzes
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
# Berechnung des Interquartilsabstands (IQR), der den Bereich der mittleren 50% der Daten darstellt
IQR = Q3 - Q1


# Identifizierung und Zählung der Ausreißer in jedem Feature des Datensatzes
# Ausreißer sind hier definiert als Werte, die mehr als 1,5 * IQR unterhalb von Q1 oder oberhalb von Q3 liegen
print("Anzeigen der Ausreißer")
print(((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum())



sns.set(style="whitegrid")  # Setzt einen sauberen Hintergrundstil

# Daten ohne das Geschlecht (Spalte "Sex") filtern
numerische_merkmale = df.drop(columns=['Sex'])

# Anzahl der numerischen Merkmale ermitteln
num_cols = numerische_merkmale.shape[1]

# Erstelle eine Figure und Axes für die Subplots
fig, axes = plt.subplots(num_cols, 1, figsize=(12, 8))

# Iterieren über die numerischen Merkmale und erstelle individuelle Boxplots
for i, col in enumerate(numerische_merkmale.columns):
    sns.boxplot(x=col, data=numerische_merkmale, ax=axes[i], fliersize=5, color="lightblue", 
                linewidth=1.25, flierprops=dict(marker='o', markersize=5, markerfacecolor='red', alpha=0.5))
    axes[i].set_title(f'Boxplot für {col}', fontsize=10)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
# Das kategoriale Merkmal 'Geschlecht' wird zuerst mittels One-Hot-Encoding in ein Set binärer Variablen transformiert,
# um es in einem maschinellen Lernmodell verwenden zu können
#
# Anzeigen der Ausreißer
# Sex                 0
# Length             49
# Diameter           59
# Height             29
# Whole weight       30
# Shucked weight     48
# Viscera weight     26
# Shell weight       35
# Rings             278
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df['Sex'] = df['Sex'].map({"M":0, "F":1, "I":2})

# %%
print('Häufigkeit der Werte in der Spalte "Sex"')
print(df['Sex'].value_counts())
# Out:
# Häufigkeit der Werte in der Spalte "Sex"
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Splitting the data into test and train

# %%
[X_train, X_test] =train_test_split(df, test_size=0.30, random_state=42, shuffle = True)

# %% [markdown]
# Saving the training and testing data in CSV files

# %%
X_train.to_csv("../data/abalone-train.csv", index=False)
X_test.to_csv("../data/abalone-test.csv", index=False)

# %% [markdown]
# Finding the attribute which has the highest Pearson correlation coefficient with the target attribute
# Rings

# %%
corr = df.corr(method = 'pearson')
print(corr['Rings'])
# Out:
# Sex                    NaN
# Length            0.556720
# Diameter          0.574660
# Height            0.557467
# Whole weight      0.540390
# Shucked weight    0.420884
# Viscera weight    0.503819
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Function for simple linear (straight-line) regression model to predict
# rings

# %%
def linear_fit(data):
    regressor = LinearRegression()
    shell_weight = np.array(data['Shell weight'])
    shell_weight = shell_weight.reshape(-1,1)
    Rings = np.array(data['Rings'])
    Rings = Rings.reshape(-1,1)
    regressor.fit(shell_weight, Rings)
    y_pred = regressor.predict(shell_weight)
    return y_pred

# %% [markdown]
# Best fit line between 'Shell weight' and 'Rings'

# %%
plt.title("Best Fit")
plt.xlabel("Shell weight")
plt.ylabel("Rings")
plt.plot(X_train['Shell weight'], linear_fit(X_train))
plt.show()

# %% [markdown]
#  The prediction accuracy on the training and data using root mean squared error

# %%
error_train = sqrt(mean_squared_error(X_train['Rings'], linear_fit(X_train))) #computing the error in train data
error_test = sqrt(mean_squared_error(X_test['Rings'],linear_fit(X_test)))#computing the error in test data
print("RMSE Error for Linear Regression, Train data is : %.2f"%(error_train))
print("RMSE Error for Linear Regression, Test data is : %.2f"%(error_test))
# Out:
# RMSE Error for Linear Regression, Train data is : 2.53
# RMSE Error for Linear Regression, Test data is : 2.47

# %% [markdown]
#  The scatter plot of actual Rings (x-axis) vs predicted Rings (y-axis) on the test data :-

# %%
plt.title("Scatter Plot") 
plt.xlabel("Rings(Actual)")
plt.ylabel("Rings(Predicted)")
plt.scatter(X_test['Rings'], linear_fit(X_test))
plt.show()

# %% [markdown]
# # Multivariate Linear Regression Model

# %% [markdown]
# Function for Multivariate linear regression model to predict rings

# %%
def multiple_fit(data):
    regressor = LinearRegression()
    input_var = np.array(data.iloc[:,:-1])
    target = np.array(data.iloc[:,-1])
    regressor.fit(input_var,target)
    pred = regressor.predict(input_var)
    return pred

# %% [markdown]
# The prediction accuracy on the training and data using root mean squared error :-

# %%
multiple_error_train = sqrt(mean_squared_error(X_train['Rings'], multiple_fit(X_train))) #computing the error in train data
multiple_error_test = sqrt(mean_squared_error(X_test['Rings'],multiple_fit(X_test)))#computing the error in test data
print("RMSE Error for Multiple Regression, Train data is : %.2f"%(multiple_error_train))
print("RMSE Error for Multiple Regression, Test data is : %.2f"%(multiple_error_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 multiple_error_train = sqrt(mean_squared_error(X_train['Rings'], multiple_fit(X_train))) #computing the error in train data
#       2 multiple_error_test = sqrt(mean_squared_error(X_test['Rings'],multiple_fit(X_test)))#computing the error in test data
#       3 print("RMSE Error for Multiple Regression, Train data is : %.2f"%(multiple_error_train))
#
# Cell In[17], line 5, in multiple_fit(data)
#       3 input_var = np.array(data.iloc[:,:-1])
#       4 target = np.array(data.iloc[:,-1])
# ----> 5 regressor.fit(input_var,target)
#       6 pred = regressor.predict(input_var)
#       7 return pred
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/linear_model/_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
#     579     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     580 )
#     582 has_sw = sample_weight is not None
#     583 if has_sw:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# The scatter plot of actual Rings (x-axis) vs predicted Rings (y-axis) on the test data :-

# %%
plt.title("Scatter Plot for multivariate regression")
plt.xlabel("Rings(Actual)")
plt.ylabel("Rings(Predicted)")
plt.scatter(X_test['Rings'], multiple_fit(X_test))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       2 plt.xlabel("Rings(Actual)")
#       3 plt.ylabel("Rings(Predicted)")
# ----> 4 plt.scatter(X_test['Rings'], multiple_fit(X_test))
#       5 plt.show()
#
# Cell In[17], line 5, in multiple_fit(data)
#       3 input_var = np.array(data.iloc[:,:-1])
#       4 target = np.array(data.iloc[:,-1])
# ----> 5 regressor.fit(input_var,target)
#       6 pred = regressor.predict(input_var)
#       7 return pred
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/linear_model/_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
#     579     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     580 )
#     582 has_sw = sample_weight is not None
#     583 if has_sw:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# # Simple Nonlinear Regression Model

# %% [markdown]
# Simple nonlinear regression model using polynomial curve fitting
# to predict Rings :-

# %%
def poly_pred(data):#Function for prediction of data
    l = []
    for i in [2,3,4,5]:
        polynomial_features = PolynomialFeatures(degree = i)
        shell_weight = np.array(data['Shell weight'])
        shell_weight = shell_weight.reshape(-1,1)
        Rings = np.array(data['Rings'])
        Rings = Rings.reshape(-1,1)
        x_poly = polynomial_features.fit_transform(shell_weight)
        regressor = LinearRegression()
        regressor.fit(x_poly, Rings)
        y_pred = regressor.predict(x_poly)
        error = sqrt(mean_squared_error(data['Rings'], y_pred))
        l.append(error)
    ls = [round(x,3) for x in l]
    return [ls,y_pred]

# %% [markdown]
# Prediction accuracy on the training and test data for the different values of degree of
# the polynomial (p = 2, 3, 4, 5) using root mean squared error (RMSE)

# %%
p = [2,3,4,5]
print("\nRMSE for Training data :-")
for i in range(len(p)):
    print("RMSE Error for p = %d is %.2f"%(p[i],poly_pred(X_train)[0][i]))
print("\nRMSE for Test data :-")
for i in range(len(p)):
    print("RMSE Error for p = %d is %.2f"%(p[i],poly_pred(X_test)[0][i]))
# Out:
# RMSE for Training data :-
# RMSE Error for p = 2 is 2.50
# RMSE Error for p = 3 is 2.48
# RMSE Error for p = 4 is 2.47
# RMSE Error for p = 5 is 2.47
#
# RMSE for Test data :-
# RMSE Error for p = 2 is 2.43
# RMSE Error for p = 3 is 2.41
# RMSE Error for p = 4 is 2.41
# RMSE Error for p = 5 is 2.41

# %% [markdown]
# Plotting the RMSE vs degree of polynomial graph :-

# %%
def plot2(data,x,y): #function for plotting RMSE vs degree of polynomial
    plt.title('Bar graph of RMSE vs degree of polynomial for %s'%(data))
    plt.xlabel('Degree of polynomial')
    plt.ylabel('RMSE')
    plt.bar(x, y, color = 'orange', width = .50)
    plt.show()
    
plot2('Traning Data',[2,3,4,5],poly_pred(X_train)[0])
plot2('Test Data',[2,3,4,5],poly_pred(X_test)[0])

# %% [markdown]
# Plotting the best fit curve using the best fit model on the training data :-

# %%
plt.title('Best Fit Polynomial') #plotting scatter plot for best fit polynomial
plt.xlabel('Shell weight')
plt.ylabel("Predicted Rings")
plt.scatter(X_train['Shell weight'],poly_pred(X_train)[1])
plt.show()

# %% [markdown]
# Plotting the scatter plot of the actual number of Rings (x-axis) vs the predicted number of
# Rings (y-axis) on the test data for the best degree of the polynomial (p) :-

# %%
plt.title('Predicted vs Real')
plt.xlabel('Actual Rings')
plt.ylabel("Predicted Rings")
plt.scatter(X_test['Rings'],poly_pred(X_test)[1])
plt.show()

# %% [markdown]
# # Multivariate Nonlinear Regression Model

# %% [markdown]
# Multivariate nonlinear regression model using polynomial regression to predict Rings :-

# %%
def multi_poly_pred(data):#Function for prediction of data
    l = []
    for i in [2,3,4,5]:
        polynomial_features = PolynomialFeatures(degree = i)
        input_var = np.array(data.iloc[:,:-1])
        x_poly = polynomial_features.fit_transform(input_var)
        Rings = np.array(data['Rings'])
        regressor = LinearRegression()
        regressor.fit(x_poly, Rings)
        y_pred = regressor.predict(x_poly)
        error = sqrt(mean_squared_error(data['Rings'], y_pred))
        l.append(error)
    ls = [round(x,3) for x in l]
    return [ls,y_pred]

# %% [markdown]
# The prediction accuracy on the training and test data for the different values of degree of
# the polynomial (p = 2, 3, 4, 5) using root mean squared error (RMSE) :-

# %%
p = [2,3,4,5]
print("\nRMSE for Training data :-")
for i in range(len(p)):
    print("RMSE Error for p = %d is %.2f"%(p[i],multi_poly_pred(X_train)[0][i]))
print("\nRMSE for Test data :-")
for i in range(len(p)):
    print("RMSE Error for p = %d is %.2f"%(p[i],multi_poly_pred(X_test)[0][i]))
# Out:
# RMSE for Training data :-
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 4
#       2 print("\nRMSE for Training data :-")
#       3 for i in range(len(p)):
# ----> 4     print("RMSE Error for p = %d is %.2f"%(p[i],multi_poly_pred(X_train)[0][i]))
#       5 print("\nRMSE for Test data :-")
#       6 for i in range(len(p)):
#
# Cell In[25], line 6, in multi_poly_pred(data)
#       4 polynomial_features = PolynomialFeatures(degree = i)
#       5 input_var = np.array(data.iloc[:,:-1])
# ----> 6 x_poly = polynomial_features.fit_transform(input_var)
#       7 Rings = np.array(data['Rings'])
#       8 regressor = LinearRegression()
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/preprocessing/_polynomial.py:322, in PolynomialFeatures.fit(self, X, y)
#     304 @_fit_context(prefer_skip_nested_validation=True)
#     305 def fit(self, X, y=None):
#     306     """
#     307     Compute number of output features.
#     308
#    (...)
#     320         Fitted transformer.
#     321     """
# --> 322     _, n_features = self._validate_data(X, accept_sparse=True).shape
#     324     if isinstance(self.degree, Integral):
#     325         if self.degree == 0 and not self.include_bias:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PolynomialFeatures does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# Plotting the RMSE vs degree of polynomial graph :-

# %%
plot2('Traning Data',[2,3,4,5],multi_poly_pred(X_train)[0])
plot2('Test Data',[2,3,4,5],multi_poly_pred(X_test)[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plot2('Traning Data',[2,3,4,5],multi_poly_pred(X_train)[0])
#       2 plot2('Test Data',[2,3,4,5],multi_poly_pred(X_test)[0])
#
# Cell In[25], line 6, in multi_poly_pred(data)
#       4 polynomial_features = PolynomialFeatures(degree = i)
#       5 input_var = np.array(data.iloc[:,:-1])
# ----> 6 x_poly = polynomial_features.fit_transform(input_var)
#       7 Rings = np.array(data['Rings'])
#       8 regressor = LinearRegression()
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/preprocessing/_polynomial.py:322, in PolynomialFeatures.fit(self, X, y)
#     304 @_fit_context(prefer_skip_nested_validation=True)
#     305 def fit(self, X, y=None):
#     306     """
#     307     Compute number of output features.
#     308
#    (...)
#     320         Fitted transformer.
#     321     """
# --> 322     _, n_features = self._validate_data(X, accept_sparse=True).shape
#     324     if isinstance(self.degree, Integral):
#     325         if self.degree == 0 and not self.include_bias:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PolynomialFeatures does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# Plotting the best fit curve using the best fit model on the training data :-

# %%
plt.title('Best Fit Polynomial') #plotting scatter plot for best fit polynomial
plt.xlabel('Shell weight')
plt.ylabel("Predicted Rings")
plt.scatter(X_train['Shell weight'],multi_poly_pred(X_train)[1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       2 plt.xlabel('Shell weight')
#       3 plt.ylabel("Predicted Rings")
# ----> 4 plt.scatter(X_train['Shell weight'],multi_poly_pred(X_train)[1])
#       5 plt.show()
#
# Cell In[25], line 6, in multi_poly_pred(data)
#       4 polynomial_features = PolynomialFeatures(degree = i)
#       5 input_var = np.array(data.iloc[:,:-1])
# ----> 6 x_poly = polynomial_features.fit_transform(input_var)
#       7 Rings = np.array(data['Rings'])
#       8 regressor = LinearRegression()
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/preprocessing/_polynomial.py:322, in PolynomialFeatures.fit(self, X, y)
#     304 @_fit_context(prefer_skip_nested_validation=True)
#     305 def fit(self, X, y=None):
#     306     """
#     307     Compute number of output features.
#     308
#    (...)
#     320         Fitted transformer.
#     321     """
# --> 322     _, n_features = self._validate_data(X, accept_sparse=True).shape
#     324     if isinstance(self.degree, Integral):
#     325         if self.degree == 0 and not self.include_bias:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PolynomialFeatures does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# Plotting the scatter plot of the actual number of Rings (x-axis) vs the predicted number of Rings (y-axis) on the test data for the best degree of the polynomial (p) :-

# %%
plt.title('Predicted vs Real')
plt.xlabel('Actual Rings')
plt.ylabel("Predicted Rings")
plt.scatter(X_test['Rings'],multi_poly_pred(X_test)[1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       2 plt.xlabel('Actual Rings')
#       3 plt.ylabel("Predicted Rings")
# ----> 4 plt.scatter(X_test['Rings'],multi_poly_pred(X_test)[1])
#       5 plt.show()
#
# Cell In[25], line 6, in multi_poly_pred(data)
#       4 polynomial_features = PolynomialFeatures(degree = i)
#       5 input_var = np.array(data.iloc[:,:-1])
# ----> 6 x_poly = polynomial_features.fit_transform(input_var)
#       7 Rings = np.array(data['Rings'])
#       8 regressor = LinearRegression()
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/preprocessing/_polynomial.py:322, in PolynomialFeatures.fit(self, X, y)
#     304 @_fit_context(prefer_skip_nested_validation=True)
#     305 def fit(self, X, y=None):
#     306     """
#     307     Compute number of output features.
#     308
#    (...)
#     320         Fitted transformer.
#     321     """
# --> 322     _, n_features = self._validate_data(X, accept_sparse=True).shape
#     324     if isinstance(self.degree, Integral):
#     325         if self.degree == 0 and not self.include_bias:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PolynomialFeatures does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# After applying Four different regression model, we found Multivariate Nonlinear Regression Model for p = 5 to be better than others as it has the least RMSE values than the other models for both training as well test data in predicting no. of rings in Abalone.

# %% [markdown]
# Deployment of the model :-

# %%
X = X_train.iloc[:, :-1]
y = X_train.iloc[:, -1]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

#Fitting model with trainig data
regressor.fit(X, y)

# Saving model to disk
pickle.dump(regressor, open('model.pkl','wb'))

# Loading model to compare the results
model = pickle.load(open('model.pkl','rb'))
print(model.predict([[0.350, 0.265, 0.090, 0.2255, 0.0995,0.0485, 0.070]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 5
#       2 regressor = LinearRegression()
#       4 #Fitting model with trainig data
# ----> 5 regressor.fit(X, y)
#       7 # Saving model to disk
#       8 pickle.dump(regressor, open('model.pkl','wb'))
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/linear_model/_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
#     579     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     580 )
#     582 has_sw = sample_weight is not None
#     583 if has_sw:
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1263, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1258         estimator_name = _check_estimator_name(estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
# -> 1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    1266     accept_large_sparse=accept_large_sparse,
#    1267     dtype=dtype,
#    1268     order=order,
#    1269     copy=copy,
#    1270     force_all_finite=force_all_finite,
#    1271     ensure_2d=ensure_2d,
#    1272     allow_nd=allow_nd,
#    1273     ensure_min_samples=ensure_min_samples,
#    1274     ensure_min_features=ensure_min_features,
#    1275     estimator=estimator,
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/.local/share/virtualenvs/DS101_DV-Ovqw0MVx/lib/python3.11/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
